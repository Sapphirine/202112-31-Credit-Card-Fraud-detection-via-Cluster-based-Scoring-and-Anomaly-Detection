# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Data Loading

# %%
#Reading .csv
df = pd.read_csv('creditcard.csv')

#Separating feature dimensions from class labels
X = df.iloc[:, :30]
y = df.iloc[:, 30].values

X = X.astype('float')
y = y.astype('float')

# %% [markdown]
# # Data Description

# %%
#Generating a summary of statistical measures for each feature dimension, e.g., mean, count, std, min-max, etc.
X.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  3.918649e-15  5.682686e-16 -8.761736e-15  2.811118e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean  -1.552103e-15  2.040130e-15 -1.698953e-15 -1.893285e-16 -3.147640e-15
# ...

# %% [markdown]
# # Variance & Standard-deviation captured by different principal-components of the dataset

# %%
#Generating Variance of each PCA component
print("Variance:")
X.iloc[:, 1:29].var(axis = 0)
# Out:
# Variance:
# V1     3.836489
# V2     2.726820
# V3     2.299029
# V4     2.004684
# V5     1.905081
# V6     1.774946
# V7     1.530401
# V8     1.426479
# V9     1.206992
# V10    1.185594
# V11    1.041855
# V12    0.998403
# V13    0.990571
# V14    0.918906
# V15    0.837803
# V16    0.767819
# V17    0.721373
# V18    0.702539
# V19    0.662662
# V20    0.594325
# V21    0.539526
# V22    0.526643
# V23    0.389951
# V24    0.366808
# V25    0.271731
# V26    0.232543
# V27    0.162919
# V28    0.108955
# dtype: float64

# %%
#Generating Standard-deviation of each PCA Component
print("Standard-deviation:")
X.iloc[:, 1:29].std(axis = 0)
# Out:
# Standard-deviation:
# V1     1.958696
# V2     1.651309
# V3     1.516255
# V4     1.415869
# V5     1.380247
# V6     1.332271
# V7     1.237094
# V8     1.194353
# V9     1.098632
# V10    1.088850
# V11    1.020713
# V12    0.999201
# V13    0.995274
# V14    0.958596
# V15    0.915316
# V16    0.876253
# V17    0.849337
# V18    0.838176
# V19    0.814041
# V20    0.770925
# V21    0.734524
# V22    0.725702
# V23    0.624460
# V24    0.605647
# V25    0.521278
# V26    0.482227
# V27    0.403632
# V28    0.330083
# dtype: float64

# %% [markdown]
# # Feature-wise histograms

# %%
plt.figure()
X.hist(figsize=(30,30))
plt.show()

# %% [markdown]
# # Class-wise frequency & Outlier Fraction

# %%
#Computing Outlier Fraction
print("Total fraudulent transactions (True Positives): " + str(len(y[y == 1])))
print("Total non-fraudulent transactions (True Positives): " + str(len(y[y == 0])))
print("")
print("Outlier Fraction (n(fraudulent)/n(non-fraudulent)): " + str(len(y[y == 1])/len(y[y == 0])))
# Out:
# Total fraudulent transactions (True Positives): 492
# Total non-fraudulent transactions (True Positives): 284315
#
# Outlier Fraction (n(fraudulent)/n(non-fraudulent)): 0.0017304750013189597

# %% [markdown]
# # Correlation heatmap

# %%
#Generating correlation among feature dimenions and plotting a heatmap
plt.figure(figsize=(10, 10))
sns.heatmap(X.corr(), square = True)
plt.show()
